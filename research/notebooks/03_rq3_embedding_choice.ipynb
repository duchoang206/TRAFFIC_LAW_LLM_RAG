# %% [markdown]
# # 03 — RQ3: Embedding model cho tiếng Việt pháp lý
#
# **Câu hỏi:** Model embedding nào cho Recall@k cao nhất trên corpus NĐ 168 + Luật 36/2024?
#
# **Ứng viên:**
# | Model | Dim | Ngôn ngữ | Ghi chú |
# | ----- | --- | -------- | ------- |
# | `KeepItReal/vietnamese-sbert` | 768 | vi | baseline hiện dùng |
# | `bkai-foundation-models/vietnamese-bi-encoder` | 768 | vi | fine-tune cho tiếng Việt, reference project dùng |
# | `intfloat/multilingual-e5-base` | 768 | multi | prefix "query:" / "passage:" |
# | `BAAI/bge-m3` | 1024 | multi | dense + sparse + multi-vector |
#
# **Metric:** Recall@{1,5,10}, MRR. Cost (tokens encode corpus, thời gian).

# %%
# --- Setup ---
import sys
from pathlib import Path

HERE = Path.cwd()
# Walk up to find traffic_rag/ (works when run from anywhere under it)
for p in [HERE] + list(HERE.parents):
    if (p / "source").is_dir() and (p / "research").is_dir():
        TRAFFIC_RAG = p
        break
else:
    raise RuntimeError("Could not locate traffic_rag/ root")

sys.path.insert(0, str(TRAFFIC_RAG))
sys.path.insert(0, str(TRAFFIC_RAG.parent))  # so `research.utils` works

from research.utils.langsmith_setup import enable_tracing
enable_tracing(project="traffic-rag-research", run_name="rq3-embedding")

EVAL_PATH = TRAFFIC_RAG / "research" / "data" / "eval_qa.jsonl"
RESULTS_DIR = TRAFFIC_RAG / "research" / "results" / "metrics"
FIGURES_DIR = TRAFFIC_RAG / "research" / "results" / "figures"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)
FIGURES_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 1. Encode corpus với mỗi embedding

# %%
# TODO: for model_name in candidates:
#   encode all chunks → Qdrant collection riêng
#   log encode latency + disk size

# %% [markdown]
# ## 2. Đo retrieval metrics (KHÔNG chạy generator)

# %%
from research.utils.metrics import recall_at_k, mrr, ndcg_at_k
# TODO: với mỗi câu trong eval_qa, query retriever → top 10 chunks →
# build `retrieved` list of citation dicts → so với gold_citations

# %% [markdown]
# ## 3. Bảng kết quả

# %%
# TODO: DataFrame: model × {Recall@1, Recall@5, Recall@10, MRR, encode_time}

# %% [markdown]
# ## Kết luận
#
# _TODO: giải thích tại sao model cuối cùng được chọn (trade-off accuracy vs latency vs free/paid)._
